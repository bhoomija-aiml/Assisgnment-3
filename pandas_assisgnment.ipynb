# %%
# part1
# Q1
import pandas as pd
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Q2
print("First 5 rows:")
print(df.head())
print("\nLast 5 rows:")
print(df.tail())
# Out:
# First 5 rows:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Q3
rows, columns = df.shape
print(f"The dataset has {rows} rows and {columns} columns.")
# Out:
# The dataset has 8807 rows and 12 columns.

# %%
# Q4
unique_countries = df['country'].nunique()
print(f"There are {unique_countries} unique countries where content is produced.")
# Out:
# There are 748 unique countries where content is produced.

# %%
# Q5
tv_shows = df[df['type'] == 'TV Show']
print("Records where the type is 'TV Show':")
print(tv_shows)
# Out:
# Records where the type is 'TV Show':
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
print(df[['date_added', 'year_added', 'month_added']].head())
# Out:
#   date_added  year_added  month_added
# 0 2021-09-25      2021.0          9.0
# 1 2021-09-24      2021.0          9.0
# 2 2021-09-24      2021.0          9.0
# 3 2021-09-24      2021.0          9.0
# 4 2021-09-24      2021.0          9.0

# %%
movies_2019 = df[(df['type'] == 'Movie') & (df['release_year'] == 2019)].shape[0]
print(f"There were {movies_2019} movies released in 2019.")
# Out:
# There were 633 movies released in 2019.

# %%
rating_counts = df['rating'].value_counts()
print("Count of each category by rating:")
print(rating_counts)
# Out:
# Count of each category by rating:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
# part2
import pandas as pd
df = pd.read_csv('world_population.csv')
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
# Q1
print("Task 1: Top 10 rows of the dataset:")
print(df.head(10))
# Out:
# Task 1: Top 10 rows of the dataset:
#    Rank CCA3    Country/Territory           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# ...

# %%
# Q2
print("\nNull Values in Each Column:")
print(df.isnull().sum())
df.dropna(inplace=True)
# Out:
# Null Values in Each Column:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
# Q3
df["2022 Population"] = pd.to_numeric(df["2022 Population"], errors='coerce')
top_5_populous = df.nlargest(5, "2022 Population")[["Country/Territory", "2022 Population"]]
print("\nTop 5 Most Populous Countries:")
print(top_5_populous)
# Out:
# Top 5 Most Populous Countries:
#     Country/Territory  2022 Population
# 41              China       1425887337
# 92              India       1417173173
# 221     United States        338289857
# 93          Indonesia        275501339
# 156          Pakistan        235824862

# %%
# Q4
if "GDP" in df.columns:
    df["GDP per Capita"] = df["GDP"] / df["2022 Population"]
    print("\nGDP per Capita added.")
else:
    print("\n'GDP' column not found — skipping GDP per Capita calculation.")
# Out:
# 'GDP' column not found — skipping GDP per Capita calculation.

# %%
# Q5
filtered_countries = df[(df["2022 Population"] > 100_000_000) & (df["Area (km²)"] < 500_000)]
print("\nCountries with Population > 100 million and Area < 500,000 km²:")
print(filtered_countries[["Country/Territory", "2022 Population", "Area (km²)"]])
# Out:
# Countries with Population > 100 million and Area < 500,000 km²:
#     Country/Territory  2022 Population  Area (km²)
# 16         Bangladesh        171186372      147570
# 102             Japan        123951692      377930
# 163       Philippines        115559009      342353

# %%
# Q6
df_sorted_by_density = df.sort_values(by="Density (per km²)", ascending=False)
print("\nTop 10 Countries by Population Density:")
print(df_sorted_by_density[["Country/Territory", "Density (per km²)"]].head(10))
# Out:
# Top 10 Countries by Population Density:
#     Country/Territory  Density (per km²)
# 119             Macau         23172.2667
# 134            Monaco         18234.5000
# 187         Singapore          8416.4634
# 89          Hong Kong          6783.3922
# 76          Gibraltar          5441.5000
# 15            Bahrain          1924.4876
# 123          Maldives          1745.9567
# 125             Malta          1687.6139
# 188      Sint Maarten          1299.2647
# 22            Bermuda          1188.5926

# %%
# part3
import pandas as pd
# Q1
matches = pd.read_csv('matches.csv')
deliveries = pd.read_csv('deliveries.csv')
matches
deliveries
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1        Kolkata Knight Riders
# 1              1       1        Kolkata Knight Riders
# 2              1       1        Kolkata Knight Riders
# 3              1       1        Kolkata Knight Riders
# 4              1       1        Kolkata Knight Riders
# ...          ...     ...                          ...
# 136593       577       2  Royal Challengers Bangalore
# 136594       577       2  Royal Challengers Bangalore
# 136595       577       2  Royal Challengers Bangalore
# 136596       577       2  Royal Challengers Bangalore
# 136597       577       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1     SC Ganguly    BB McCullum
# 1       Royal Challengers Bangalore     1     2    BB McCullum     SC Ganguly
# 2       Royal Challengers Bangalore     1     3    BB McCullum     SC Ganguly
# ...

# %%
# Q2
most_successful_team = matches['winner'].value_counts().idxmax()
most_wins = matches['winner'].value_counts().max()
print(f"Most successful team: {most_successful_team} with {most_wins} wins")
# Out:
# Most successful team: Mumbai Indians with 80 wins

# %%
# Q3
matches_per_season = matches['season'].value_counts().sort_index()
print("\nMatches per Season:")
print(matches_per_season)
# Out:
# Matches per Season:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# Name: count, dtype: int64

# %%
# Q4
top_players = matches['player_of_match'].value_counts().head(5)
print("\nTop 5 Players with Most 'Player of the Match' Awards:")
print(top_players)
# Out:
# Top 5 Players with Most 'Player of the Match' Awards:
# player_of_match
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
# Name: count, dtype: int64

# %%
# Q5
merged_df = deliveries.merge(matches, left_on='match_id', right_on='id')
# Example analysis from merged data:
# Top 5 run scorers overall
top_scorers = merged_df.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(5)
print("\nTop 5 Run Scorers Overall:")
print(top_scorers)
# Out:
# Top 5 Run Scorers Overall:
# batsman
# V Kohli      4115
# SK Raina     4106
# RG Sharma    3874
# G Gambhir    3634
# CH Gayle     3451
# Name: batsman_runs, dtype: int64

# %%
# part4
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Q1
avg_math = df['math score'].mean()
avg_reading = df['reading score'].mean()
avg_writing = df['writing score'].mean()

print("Average Math Score:", round(avg_math, 2))
print("Average Reading Score:", round(avg_reading, 2))
print("Average Writing Score:", round(avg_writing, 2))
# Out:
# Average Math Score: 66.09
# Average Reading Score: 69.17
# Average Writing Score: 68.05

# %%
# Q2
gender_avg_writing = df.groupby('gender')['writing score'].mean()
print("\nAverage Writing Score by Gender:")
print(gender_avg_writing)

better_writer = gender_avg_writing.idxmax()
print(f"\n{better_writer.capitalize()}s performed better in writing on average.")
# Out:
# Average Writing Score by Gender:
# gender
# female    72.467181
# male      63.311203
# Name: writing score, dtype: float64
#
# Females performed better in writing on average.

# %%
# Q3
df['total score'] = df['math score'] + df['reading score'] + df['writing score']
df['percentage'] = df['total score'] / 3

# %%
# Q4
grouped_avg = df.groupby('parental level of education')[['math score', 'reading score', 'writing score']].mean()

grouped_avg.plot(kind='bar', figsize=(12, 6))
plt.title('Average Scores by Parental Level of Education')
plt.ylabel('Average Score')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Subject')
plt.show()

# %%
# Q5
top_students = df[(df['math score'] >= 90) & (df['reading score'] >= 90) & (df['writing score'] >= 90)]
print(f"\nNumber of students who scored above 90 in all subjects: {len(top_students)}")
print(top_students[['gender', 'math score', 'reading score', 'writing score', 'percentage']])
# Out:
# Number of students who scored above 90 in all subjects: 28
#      gender  math score  reading score  writing score  percentage
# 2    female          90             95             93   92.666667
# 114  female          99            100            100   99.666667
# 149    male         100            100             93   97.666667
# 165  female          96            100            100   98.666667
# 179  female          97            100            100   99.000000
# 263  female          99             93             90   94.000000
# 451  female         100             92             97   96.333333
# 458  female         100            100            100  100.000000
# 474  female          90             90             91   90.333333
# 546  female          92            100             97   96.333333
# 562    male          96             90             92   92.666667
# 566  female          92            100            100   97.333333
# ...

# %%
# part5
import pandas as pd

# Load CSV
df = pd.read_csv('Clean_Dataset.csv')

# Q1. Display info and describe
print(df.info())
print(df.describe(include='all'))

# Q2. Convert to datetime — skipped (no actual date columns)

# Q3. Create Journey Day and Month columns
# Skipped because no proper date column is available

# Q4. Find most frequent airline and source city
most_freq_airline = df['airline'].value_counts().idxmax()
most_freq_source = df['source_city'].value_counts().idxmax()
print("Most frequent airline:", most_freq_airline)
print("Most frequent source city:", most_freq_source)

# Q5. Remove duplicates and handle missing values
df = df.drop_duplicates()
df = df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB
# None
#            Unnamed: 0  airline  flight source_city departure_time   stops  \
# ...
